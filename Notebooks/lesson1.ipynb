# %%
import pandas
data = pandas.read_csv("bank.csv")
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.corr()
# Out:
# C:\Users\Lilian Mogute\AppData\Local\Temp\ipykernel_9904\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# ...

# %%
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

plt.style.available
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn")

# %%
sns.countplot(x='Gender', data=data, palette= 'Reds')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Number of members')
# Out:
# Text(0, 0.5, 'Number of members')

# %%
import numpy
sns.barplot(x='Gender', y='LoanAmount', data=data, estimator=numpy.mean, palette='magma', hue='Education')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Loan Amount')
# Out:
# c:\Users\Lilian Mogute\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# Text(0, 0.5, 'Loan Amount')

# %%
sns.scatterplot(x='LoanAmount', y='ApplicantIncome', data = data, palette = 'Blues', hue='Gender')
# Out:
# <Axes: xlabel='LoanAmount', ylabel='ApplicantIncome'>

# %%
data.groupby('Property_Area').size().plot(kind='pie', autopct='%1.2f%%')
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('bank.csv')

# Calculate education counts
education_counts = data['Education'].value_counts()

# Plot pie chart
plt.pie(education_counts, labels=education_counts.index, autopct='%1.2f%%')
plt.title('Education Distribution')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('bank.csv')

# Plot count plot
sns.countplot(data=data, x='Loan_Status')
plt.title('Loan Status Distribution')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy

# Load data
data = pd.read_csv('bank.csv')

sns.barplot(x="Gender", y="LoanAmount", palette="Oranges", data=data, estimator=numpy.mean, hue="Education")
plt.title("Education and Loan Amount")
plt.xlabel("Gender")
plt.ylabel("Education")
# Out:
# c:\Users\Lilian Mogute\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# Text(0, 0.5, 'Education')

# %%
#From the chart, we can see that there is a positive
# correlation between education level and average loan 
# amount. This means that individuals with higher education especially males
#  tend to have higher loan amounts on average.
